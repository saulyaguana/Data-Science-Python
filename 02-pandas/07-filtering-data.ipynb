# %%
import pandas as pd

# %%
df = pd.read_csv("./Online_Retail.csv", encoding="windows-1252")
df.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
df.dropna(subset=["CustomerID", "InvoiceDate"], inplace=True)
df["TotalPrice"] = df["Quantity"] * df["UnitPrice"]
# Out:
# C:\Users\Usuario iTC\AppData\Local\Temp\ipykernel_18124\2526273290.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
df.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
# Filter by sales in UK
df[df["Country"] == "United Kingdom"].head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00

# %%
df[df["Quantity"] > 20].head(3)
# Out:
#    InvoiceNo StockCode                    Description  Quantity  \
# 9     536367     84879  ASSORTED COLOUR BIRD ORNAMENT        32
# 26    536370     22728      ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727      ALARM CLOCK BAKELIKE RED         24
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 9  2010-12-01 08:34:00       1.69     13047.0  United Kingdom       54.08
# 26 2010-12-01 08:45:00       3.75     12583.0          France       90.00
# 27 2010-12-01 08:45:00       3.75     12583.0          France       90.00

# %%
df[(df["Quantity"] > 20) & (df["Country"] == "United Kingdom")].head()
# Out:
#    InvoiceNo StockCode                        Description  Quantity  \
# 9     536367     84879      ASSORTED COLOUR BIRD ORNAMENT        32
# 46    536371     22086    PAPER CHAIN KIT 50'S CHRISTMAS         80
# 65    536374     21258         VICTORIAN SEWING BOX LARGE        32
# 82    536376     22114  HOT WATER BOTTLE TEA AND SYMPATHY        48
# 83    536376     21733   RED HANGING HEART T-LIGHT HOLDER        64
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 9  2010-12-01 08:34:00       1.69     13047.0  United Kingdom       54.08
# 46 2010-12-01 09:00:00       2.55     13748.0  United Kingdom      204.00
# 65 2010-12-01 09:09:00      10.95     15100.0  United Kingdom      350.40
# 82 2010-12-01 09:32:00       3.45     15291.0  United Kingdom      165.60
# 83 2010-12-01 09:32:00       2.55     15291.0  United Kingdom      163.20

# %%
df[df["InvoiceDate"].dt.year == 2011].head(4)
# Out:
#       InvoiceNo StockCode               Description  Quantity  \
# 42481    539993     22386   JUMBO BAG PINK POLKADOT        10
# 42482    539993     21499        BLUE POLKADOT WRAP        25
# 42483    539993     21498       RED RETROSPOT WRAP         25
# 42484    539993     22379  RECYCLING BAG RETROSPOT          5
#
#               InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 42481 2011-01-04 10:00:00       1.95     13313.0  United Kingdom        19.5
# 42482 2011-01-04 10:00:00       0.42     13313.0  United Kingdom        10.5
# 42483 2011-01-04 10:00:00       0.42     13313.0  United Kingdom        10.5
# 42484 2011-01-04 10:00:00       2.10     13313.0  United Kingdom        10.5

# %%
df[(df["InvoiceDate"].dt.year == 2011) & (df["InvoiceDate"].dt.month == 2)]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 77628     542776     21671       RED SPOT CERAMIC DRAWER KNOB        48
# 77629     542776     21668     RED STRIPE CERAMIC DRAWER KNOB        12
# 77630     542776     21670      BLUE SPOT CERAMIC DRAWER KNOB        12
# 77631     542776    17013D       ORIGAMI ROSE INCENSE IN TUBE        96
# 77632     542776     17096  ASSORTED LAQUERED INCENSE HOLDERS        48
# ...          ...       ...                                ...       ...
# 105329    545218    85099B            JUMBO BAG RED RETROSPOT        10
# 105330    545218     21936           RED RETROSPOT PICNIC BAG         5
# 105331    545218     21932    SCANDINAVIAN PAISLEY PICNIC BAG         5
# 105332    545218     22386            JUMBO BAG PINK POLKADOT        10
# 105333    545218     21933    PINK VINTAGE PAISLEY PICNIC BAG         5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...
